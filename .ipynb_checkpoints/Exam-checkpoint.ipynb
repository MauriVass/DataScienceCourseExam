# %%
#https://www.linkedin.com/pulse/text-classification-using-bag-words-approach-nltk-scikit-rajendran/
#https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/
#https://www.datacamp.com/community/tutorials/text-analytics-beginners-nltk
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
import nltk
from sklearn.utils import shuffle
import sklearn

# %%
dev = pd.read_csv('development.csv')
print(len(dev))
# Out:
# 28754

# %%
from numpy.random import rand
counter = 0
for i,r in dev.iterrows():
    n = rand()
    if r[1] == 'pos' and counter<10000 and n < 0.5:
        dev = dev.drop(i,axis=0)
        counter = counter + 1
print(len(dev))
# Out:
# 18968

# %%
eva = pd.read_csv('evaluation.csv')

# %%
posWords = pd.read_csv('ListPositiveWord.csv',skiprows=1)
negWords = pd.read_csv('ListNegativeWord.csv',skiprows=1)

# %%
import re
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.snowball import ItalianStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords as sw

stop_words = sw.words('italian')#+['hotel','stanza','ristorante','guardare','cosa','persone','acqua','cibo','soggiornato','terrazza','visita','quali','trova','taxi','piscina','quando','opzione','vario','servizio','pranzo','vedute','utilizzato','viene','settimana','presto','pasta','stesso','venezia','torino','ross','milano','turistico','selezione','venezia','staff','mattino','presto','iniziare','me','senso','zona','tipo','spazi','varia','valigie','vini','vado','etc','stanchi','cereali','pernottato','zone','vedi']
frequent = ['hotel','albergo','camera','zoomarine','zone','zona','prima','volta','volte']+\
['colazione','pranzo','cena','cibo'+'yogurt','frutta','cereali','zucchero','caffe','acqua']+\
['venezia',',milano','roma','ischia','vacanza','viaggio','visita','vista','visto','visti','viste','camere','vedere','stato','paese','citta','italia','collina','montagna','strada','piscina','spiaggia','mare','giugno','luglio','agosto','settembre','terrazza']+\
['stata','vuole','vuoi','vuol','vorrei','vorremmo','voluto','voluti','vorrebbe','volete','volevamo','volevo','voler''vogliamo','vogliano','vogliate','voglio','vogliono','volendo','voleva','volevano','voglia','vogliamo','voler','volere','volesse']+\
['windows','week','weekend','western','suite','wellness','wagner','westin','york','wonderbox','reception','autobus']+\
['roberta','mario','luigi','quali','parla','brioche','ristorante']
unfrequent = ['abbandonata','abbandonato','abbandono','abbassare','abbastanza','abbazia', 'abbigliamento', 'abbondante', 'abbondante', 'abbondanti', 'abbondantissima', 'abbondanza', 'abbraccio', 'abiti', 'abituale', 'abituati', 'abituato', 'abitudine', 'abruzzo', 'acari', 'accade', 'accademia', 'accadere', 'accaduto', 'accanto','accappatoi', 'accappatoio', 'accattivante', 'accede', 'accedere', 'accende', 'accendere', 'accesa', 'acceso', 'accessibile', 'accessibili', 'accesso', 'accessori','accessoriate', 'accetta', 'accettabile', 'accettabili', 'accettano', 'accettare', 'accettato', 'accoglie', 'accogliente', 'accoglienti','accoglienza','accogliere','accolgono','accolta','accolti','accolto','accomodante','accomodare','accompagna','accompagnamento','accompagnano','accompagnata','accompagnati','accompagnato','accontentare','accontentati','accontentato','accordi','accordo','accorgo','accortezza','accorti','accorto','accostati','accurata','accuratamente','accurate','accurato','acqua']
include_words = ['no','non','mai','ben','bel','caro']

stop_words=stop_words+frequent
def CleanSentence(sentence,sw=stop_words):
    sentence = sentence.lower()
    #Remove Special characters
    sentence = re.sub("`!@#$%^&*()_+-\{}|;'':,./<>?", "", sentence)
    #Remove digits
    sentence = re.sub("(\\d|\\W)+", " ", sentence)
    stemmer=SnowballStemmer("italian")
    sentence = stemmer.stem(sentence)
    newSentence = ""
    removed_s = []
    removed_c = []
    min = 4
    max = 18
    c = 0
    for word in sentence.split():
        if word not in stop_words:
            if  (min < len(word) < max or word in include_words):
                newSentence = newSentence + word + " "
            else:
                removed_c.append(word)
        else:
            removed_s.append(word)
    #        c = c +1
    #print(c)
    if(False):
        #print(removed_s)
        if(len(removed_c)>0):
            print()
            print(removed_c)
            print("--- ---- ----")
    return newSentence

def CleanText(text):
    sentences = []
    for row in text:
        sentences.append(CleanSentence(row))
    
    return sentences

# %%
dev['clean'] = CleanText(dev['text'])

# %%
#Balanc the classes: Normal: 2/3 pos, 1/3 neg
for i,r in dev.iterrows():
    if r[1] == 'neg':
        dev = dev.append(r)
# Out:
# 37976

# %%
posWords['clean'] = CleanSentence(posWords.iloc[0,0])
negWords['clean'] = CleanSentence(negWords.iloc[0,0])

# %%
dev = dev.append(posWords)
dev = dev.append(negWords)
dev = dev.reset_index(drop=True)

# %%
eva['clean'] = CleanText(eva['text'])

# %%
#NO
counter_text = []
words_text = {}
for s in dev['text']:
    counter_text.append(len(s.split()))
    for w in s.split():
        if w not in words_text:
            words_text[w] = 1
        words_text[w] = words_text[w] + 1

# %%
#NO
counter_text_eva = []
words_text_eva = {}
for s in eva['text']:
    counter_text_eva.append(len(s.split()))
    for w in s.split():
        if w not in words_text_eva:
            words_text_eva[w] = 1
        words_text_eva[w] = words_text_eva[w] + 1

# %%
#NO
counter_clean = []
words_clean = {}
for index, row in dev.iterrows():
    counter_clean.append(len(row[2].split()))
    for w in row[2].split():
        if w not in words_clean:
            words_clean[w] = 1
        words_clean[w] = words_clean[w] + 1

# %%
#NO
counter_clean_eva = []
words_clean_eva = {}
for index, row in eva.iterrows():
    counter_clean_eva.append(len(row[1].split()))
    for w in row[1].split():
        if w not in words_clean_eva:
            words_clean_eva[w] = 1
        words_clean_eva[w] = words_clean_eva[w] + 1

# %%
print(f'{len(words_text)} {len(words_clean)}')
# Out:
# 153276 49557

# %%
print(f'{len(words_text_eva)} {len(words_clean_eva)}')
# Out:
# 89558 33262

# %%
#NO
fig, ax = plt.subplots()
ax.scatter(range(0,len(counter_text)),counter_text,s=1,c='green',label='Development')
ax.scatter(range(0,len(counter_text_eva)),counter_text_eva,s=1,c='red',label='Evaluation')
print(f'means: {np.mean(counter_text)} {np.mean(counter_text_eva)}')
print(f'stds: {np.std(counter_text)} {np.std(counter_text_eva)}')

ax.legend(loc="upper right",fontsize=12)
ax.grid(True)

plt.show()
# Out:
# means: 113.55035821103151 113.11855879250183
# stds: 100.67431714434085 100.60579541968868

# %%
#NO
fig, ax = plt.subplots()
plt.hist(counter_text,label='Development',color='green')
plt.hist(counter_text_eva,label='Evaluation',color='red')

ax.legend(loc="upper right",fontsize=12)
ax.grid(True)

plt.show()

# %%
#NO
fig, ax = plt.subplots()
ax.scatter(range(0,len(counter_clean)),counter_text,s=1,c='green',label='Development')
ax.scatter(range(0,len(counter_clean_eva)),counter_text_eva,s=1,c='red',label='Evaluation')
print(f'means: {np.mean(counter_clean)} {np.mean(counter_clean_eva)}')
print(f'stds: {np.std(counter_clean)} {np.std(counter_clean_eva)}')

ax.legend(loc="upper right",fontsize=12)
ax.grid(True)

plt.show()
# Out:
# means: 56.54797553774779 53.56609591820174
# stds: 47.98939563193015 44.70404986761067

# %%
#NO
fig, ax = plt.subplots()
plt.hist(counter_clean,label='Development',color='green')
plt.hist(counter_clean_eva,label='Evaluation',color='red')

ax.legend(loc="upper right",fontsize=12)
ax.grid(True)

plt.show()

# %%
#NO
p = {'pos':0,'neg':0}
for i,r in dev.iterrows():
    if r[1] == 'pos':
        p['pos']  = p['pos'] + 1
    else:
        p['neg']  = p['neg'] + 1
print(f"Positive {p['pos']} Negative {p['neg']}")
# Out:
# Positive 9746 Negative 9222

# %%
plt.bar(p.keys(), p.values())
# Out:
# <BarContainer object of 2 artists>

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from sklearn.feature_extraction .text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.util import ngrams

max_feature = len(dev['clean'])
print(f'#Feature {max_feature}')

def X_tfidf(sentences,max_feature = max_feature):  
    tfidf = TfidfVectorizer(min_df=20, max_df=0.81, ngram_range=(1,2),lowercase=False)
    X = tfidf.fit_transform(sentences)
    return X, tfidf
#Feature 28754
# Out:
# #Feature 28754

# %%
from sklearn.model_selection import train_test_split
if(True):
    dev = pd.read_csv('development.csv')
    dev['clean'] = CleanText(dev['text'])
X, vectorizer = X_tfidf(dev.iloc[:,2])

X_train, X_test, y_train, y_test = train_test_split(X,dev.iloc[:,1],test_size=0.1,random_state=0)

# %%
Y = vectorizer.transform(eva.iloc[:,1])

# %%
#NO
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold 
X_train, X_test, y_train, y_test = train_test_split(X,dev.iloc[:,1],test_size=0.20,random_state=0,shuffle=False)

kf = RepeatedKFold(n_splits=50, n_repeats=5, random_state=0) 
#kf = KFold(n_splits=10, random_state=0) 
labels = dev.iloc[:,1]

sgd1 = SGDClassifier()

#X_ins = X_train
#y_ins = y_train

X_ins = X
y_ins = dev.iloc[:,1]
score = []
for train_index, test_index in kf.split(X_ins):
    X_tr, X_te = X_ins[train_index], X_ins[test_index] 
    y_tr, y_te = y_ins[train_index], y_ins[test_index]
    sgd1.fit(X_tr,y_tr)
    y_p = sgd1.predict(X_te)
    score.append(f1_score(y_te, y_p, average='weighted'))
#train_model(sgd, X_train, X_test, y_train, y_test)
np.mean(score)

# %%
#NO
y_pr = sgd1.predict(X_test)
print(f"#f1 Score: {f1_score(y_test, y_pr, average='weighted')}")
y_eval = sgd1.predict(Y)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
def train_model(classifier, X_train, X_test, y_train, y_test, printAll=False, printSomething=True):
    # fit the training dataset on the classifier
    classifier.fit(X_train, y_train)
    
    # predict the labels on validation dataset
    y_pred = classifier.predict(X_test)
    
    if(printSomething):
        print(f"#Accurancy: {accuracy_score(y_test, y_pred):.5f}")
        print(f"#f1 Score: {f1_score(y_test, y_pred, average='weighted'):.5f}")
        
    if(printAll):
        print(confusion_matrix(y_test,y_pred))      
        print(classification_report(y_test,y_pred))
    print("#--- --- ---")

# %%
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB

# Naive Bayes on Word Level TF IDF Vectors
mNB = MultinomialNB()
train_model(mNB, X_train.todense(), X_test.todense(), y_train, y_test)
bNB = BernoulliNB()
train_model(bNB, X_train.todense(), X_test.todense(), y_train, y_test)
gNB = GaussianNB()
train_model(gNB, X_train.todense(), X_test.todense(), y_train, y_test)
#Accurancy: 0.95410
#f1 Score: 0.95371
#--- --- ---
#Accurancy: 0.93533
#f1 Score: 0.93501
#--- --- ---
#Accurancy: 0.90821
#f1 Score: 0.90888
#--- --- ---
# Out:
# #Accurancy: 0.95306
# #f1 Score: 0.95268
# #--- --- ---
# #Accurancy: 0.93602
# #f1 Score: 0.93569
# #--- --- ---
# #Accurancy: 0.90612
# #f1 Score: 0.90687
# #--- --- ---

# %%
y_eval = mNB.predict(Y)

# %%
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

for i in range(10,110,10):
    print(i/100)
    lsvc = LinearSVC(tol=1e-8,max_iter=100000,random_state=0,C=i/100, penalty='l2')
    train_model(lsvc, X_train, X_test, y_train, y_test)

svc = SVC(random_state=0,kernel='linear')
#train_model(svc, X_train, X_test, y_train, y_test)
# Out:
# 0.1
# #Accurancy: 0.95793
# #f1 Score: 0.95760
# #--- --- ---
# 0.2
# #Accurancy: 0.96106
# #f1 Score: 0.96085
# #--- --- ---
# 0.3
# #Accurancy: 0.96071
# #f1 Score: 0.96051
# #--- --- ---
# 0.4
# #Accurancy: 0.96036
# #f1 Score: 0.96017
# #--- --- ---
# 0.5
# #Accurancy: 0.96001
# #f1 Score: 0.95985
# #--- --- ---
# 0.6
# #Accurancy: 0.96071
# #f1 Score: 0.96057
# #--- --- ---
# 0.7
# #Accurancy: 0.95862
# #f1 Score: 0.95849
# #--- --- ---
# 0.8
# #Accurancy: 0.95862
# #f1 Score: 0.95849
# #--- --- ---
# 0.9
# #Accurancy: 0.95688
# #f1 Score: 0.95674
# #--- --- ---
# 1.0
# #Accurancy: 0.95688
# #f1 Score: 0.95672
# #--- --- ---

# %%
lsvc = LinearSVC(tol=1e-8,max_iter=10000,random_state=0,C=70/100, penalty='l2')
train_model(lsvc, X_train, X_test, y_train, y_test)
y_eval = svc.predict(Y)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(penalty='l2',max_iter=1000,random_state=0)
train_model(lr, X_train, X_test, y_train, y_test)
#Accurancy: 0.9548
#f1 Score: 0.9543
#--- --- ---
# Out:
# #Accurancy: 0.95549
# #f1 Score: 0.95508
# #--- --- ---

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=520, random_state=0)
train_model(classifier, X_train, X_test, y_train, y_test)
#Accurancy: 0.9286
#f1 Score: 0.9272
#--- --- ---
# Out:
# #Accurancy: 0.92455
# #f1 Score: 0.92291
# #--- --- ---

# %%
y_eval = classifier.predict(Y)

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier(validation_fraction=0.1)
train_model(sgd, X_train, X_test, y_train, y_test,printAll=True)
#Accurancy: 0.9633750579508576
#f1 Score: 0.9632102921397484
#Accurancy: 0.9629
#f1 Score: 0.9627
#--- --- ---
# Out:
# #Accurancy: 0.96384
# #f1 Score: 0.96365
# [[ 893   71]
#  [  33 1879]]
#               precision    recall  f1-score   support
#
#          neg       0.96      0.93      0.94       964
#          pos       0.96      0.98      0.97      1912
#
#     accuracy                           0.96      2876
#    macro avg       0.96      0.95      0.96      2876
# weighted avg       0.96      0.96      0.96      2876
#
# #--- --- ---

# %%
y_eval = sgd.predict(Y)

# %%
from sklearn.neighbors import KNeighborsClassifier

score = []
for i in range(2,100,2):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    sco = f1_score(y_test, y_pred, average='weighted')
    score.append(sco)
    print(f'{i} {sco:.4f}')

# %%
def WriteOnFile(name):
    f = open(name,"w")
    f.write("Id,Predicted\n")
    for index,i in enumerate(y_eval):
        f.write(f"{index},{i}\n")
    f.close

# %%
WriteOnFile("out20.csv")

# %%
for i in range(0,40):
    if y_eval[i] != 'pos':
        print(f"{i} {y_eval[i]}")
# Out:
# 1 neg
# 3 neg
# 5 neg
# 7 neg
# 10 neg
# 11 neg
# 12 neg
# 13 neg
# 14 neg
# 16 neg
# 17 neg
# 20 neg
# 21 neg
# 23 neg
# 26 neg
# 28 neg
# 34 neg
# 35 neg

# %%
frequent_word = []
for i in sorted(vectorizer.vocabulary_.items(), key = lambda kv:(kv[1])):
    frequent_word.append(i)

# %%
frequent_word[-50:-1]
# Out:
# [('visitato', 11254),
#  ('visitato milano', 11255),
#  ('visitatore', 11256),
#  ('visitatori', 11257),
#  ('visite', 11258),
#  ('visite turistiche', 11259),
#  ('vissuta', 11260),
#  ('vissuto', 11261),
#  ('visuale', 11262),
#  ('vittoria', 11263),
#  ('vittorio', 11264),
#  ('vittorio emanuele', 11265),
#  ('viuzze', 11266),
#  ('vivace', 11267),
#  ('vivamente', 11268),
#  ('vivamente albergo', 11269),
#  ('vivamente chiunque', 11270),
#  ('vivamente consigliato', 11271),
#  ('vivamente posizione', 11272),
#  ('vivamente posto', 11273),
#  ('vivamente soggiornare', 11274),
#  ('vivamente soggiorno', 11275),
#  ('vivere', 11276),
#  ('vivibile', 11277),
#  ('vivono', 11278),
#  ('viziati', 11279),
#  ('volare', 11280),
#  ('volentieri', 11281),
#  ('volontà', 11282),
#  ('volto', 11283),
#  ('volume', 11284),
#  ('vomero', 11285),
#  ('voucher', 11286),
#  ('vuota', 11287),
#  ('vuote', 11288),
#  ('vuoti', 11289),
#  ('vuoto', 11290),
#  ('water', 11291),
#  ('windsor', 11292),
#  ('wireless', 11293),
#  ('world', 11294),
#  ('yogurt', 11295),
#  ('yogurt succhi', 11296),
#  ('zaccaria', 11297),
#  ('zampe', 11298),
#  ('zanzare', 11299),
#  ('zanzare camera', 11300),
#  ('zanzariere', 11301),
#  ('zecca', 11302)]

# %%
frequent_word[0:150]
# Out:
# [('acquatico', 0),
#  ('acque', 1),
#  ('acqueo', 2),
#  ('acquistare', 3),
#  ('acquistare biglietti', 4),
#  ('acquistare biglietto', 5),
#  ('acquistati', 6),
#  ('acquistato', 7),
#  ('acquistato coupon', 8),
#  ('acquisto', 9),
#  ('acustico', 10),
#  ('adatta', 11),
#  ('adatte', 12),
#  ('adatti', 13),
#  ('adatto', 14),
#  ('adatto bambini', 15),
#  ('adatto famiglie', 16),
#  ('addebitato', 17),
#  ('addebito', 18),
#  ('addestrato', 19),
#  ('addetta', 20),
#  ('addetta reception', 21),
#  ('addette', 22),
#  ('addetti', 23),
#  ('addetti pulizie', 24),
#  ('addetti reception', 25),
#  ('addetto', 26),
#  ('addetto reception', 27),
#  ('addetto ricevimento', 28),
#  ('addio', 29),
#  ('addirittura', 30),
#  ('addosso', 31),
#  ('adeguata', 32),
#  ('adeguatamente', 33),
#  ('adeguate', 34),
#  ('adeguati', 35),
#  ('adeguato', 36),
#  ('adesso', 37),
#  ('adiacente', 38),
#  ('adiacenti', 39),
#  ('adige', 40),
#  ('adolescenti', 41),
#  ('adorabile', 42),
#  ('adoro', 43),
#  ('adulti', 44),
#  ('adulti bambini', 45),
#  ('advisor', 46),
#  ('aereo', 47),
#  ('aeroporti', 48),
#  ('aeroporto', 49),
#  ('aeroporto linate', 50),
#  ('aeroporto malpensa', 51),
#  ('aeroporto marco', 52),
#  ('aeroporto minuti', 53),
#  ('aeroporto molto', 54),
#  ('aeroporto personale', 55),
#  ('aeroporto stazione', 56),
#  ('affabile', 57),
#  ('affaccia', 58),
#  ('affaccia canal', 59),
#  ('affaccia canale', 60),
#  ('affaccia strada', 61),
#  ('affacciano', 62),
#  ('affacciano strada', 63),
#  ('affacciata', 64),
#  ('affacciato', 65),
#  ('affacciava', 66),
#  ('affacciava canal', 67),
#  ('affacciava canale', 68),
#  ('affacciava cortile', 69),
#  ('affacciava strada', 70),
#  ('affaccio', 71),
#  ('affamati', 72),
#  ('affare', 73),
#  ('affari', 74),
#  ('affascinante', 75),
#  ('affascinanti', 76),
#  ('affascinati', 77),
#  ('affatto', 78),
#  ('affermare', 79),
#  ('affermato', 80),
#  ('affettati', 81),
#  ('affettati formaggi', 82),
#  ('affianco', 83),
#  ('affidabile', 84),
#  ('affinchè', 85),
#  ('affittare', 86),
#  ('affluenza', 87),
#  ('affollata', 88),
#  ('affollate', 89),
#  ('affollato', 90),
#  ('affreschi', 91),
#  ('affrontare', 92),
#  ('affrontato', 93),
#  ('affumicato', 94),
#  ('agente', 95),
#  ('agenzia', 96),
#  ('agenzia viaggi', 97),
#  ('agevole', 98),
#  ('agevolmente', 99),
#  ('aggiornamento', 100),
#  ('aggiornare', 101),
#  ('aggiornato', 102),
#  ('aggiunge', 103),
#  ('aggiungendo', 104),
#  ('aggiungere', 105),
#  ('aggiungo', 106),
#  ('aggiunta', 107),
#  ('aggiuntivi', 108),
#  ('aggiuntivo', 109),
#  ('aggiunto', 110),
#  ('agosto', 111),
#  ('agriturismo', 112),
#  ('ahimè', 113),
#  ('aires', 114),
#  ('aiuta', 115),
#  ('aiutano', 116),
#  ('aiutarci', 117),
#  ('aiutare', 118),
#  ('aiutarmi', 119),
#  ('aiutarti', 120),
#  ('aiutarvi', 121),
#  ('aiutati', 122),
#  ('aiutato', 123),
#  ('aiuto', 124),
#  ('albergatore', 125),
#  ('albergatori', 126),
#  ('alberghi', 127),
#  ('alberghi alloggiato', 128),
#  ('alberghi belli', 129),
#  ('alberghi italia', 130),
#  ('alberghi mai', 131),
#  ('alberghi migliori', 132),
#  ('alberghi milano', 133),
#  ('alberghi molto', 134),
#  ('alberghi stelle', 135),
#  ('alberghiera', 136),
#  ('alberghiere', 137),
#  ('alberghiero', 138),
#  ('albergo', 139),
#  ('albergo bello', 140),
#  ('albergo ben', 141),
#  ('albergo buona', 142),
#  ('albergo camera', 143),
#  ('albergo camere', 144),
#  ('albergo carino', 145),
#  ('albergo centro', 146),
#  ('albergo davvero', 147),
#  ('albergo lusso', 148),
#  ('albergo molto', 149)]

# %%
t = dev.iloc[:,0]
r = dev.iloc[:,1]
m = {}
m['pos'] = []
m['neg'] = []
for i in range(len(r)):
    if r[i] == 'pos':
        m['pos'].append(len(t[i]))
    else:
        m['neg'].append(len(t[i]))

# %%
from wordcloud import WordCloud
def Word_Cloud(words):
    text = ""
    for i in words[1:-1]:
        if len(i[0].split(' ')) ==1:
             text = text + " " + i[0]
    plt.figure( figsize=(20,10), facecolor='k')
    wordcloud= WordCloud(width=800, height=400,min_font_size=8, max_font_size=100, max_words=300, background_color="white",contour_color='white').generate(text)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    #print(text)

# %%
Word_Cloud(list(vectorizer.vocabulary_.items()))

# %%
Word_Cloud(list(vectorizer.vocabulary_.items()))

# %%
list(vectorizer.vocabulary_.items())
# Out:
# [('lussuoso', 5181),
#  ('mai', 5218),
#  ('soggiornato', 9506),
#  ('esperienza', 3618),
#  ('complessiva', 2328),
#  ('prima', 7666),
#  ('classe', 2073),
#  ('direttamente', 3081),
#  ('iniziale', 4745),
#  ('reception', 8274),
#  ('roberta', 8731),
#  ('servizio', 9250),
#  ('cordiale', 2638),
#  ('efficiente', 3503),
#  ('ristorante', 8616),
#  ('terrazza', 10480),
#  ('avviso', 869),
#  ('eccezionale', 3466),
#  ('piccolo', 7001),
#  ('camere', 1594),
#  ('molti', 5685),
#  ('quali', 8036),
#  ('parla', 6496),
#  ('tutte', 10852),
#  ('sapientemente', 8857),
#  ('gestito', 4245),
#  ('sotto', 9647),
#  ('occhio', 6174),
#  ('mario', 5329),
#  ('grande', 4397),
#  ('squadra', 9821),
#  ('trova', 10746),
#  ('scogliera', 8976),
#  ('fuori', 4122),
#  ('porto', 7203),
#  ('principale', 7717),
#  ('ischia', 4878),
#  ('facile', 3755),
#  ('raggiungere', 8200),
#  ('piedi', 7020),
#  ('verso', 11145),
#  ('basso', 988),
#  ('torna', 10549),
#  ('collina', 2240),
#  ('autobus', 821),
#  ('caro', 1776),
#  ('fiera', 3933),
#  ('fisso', 3974),
#  ('minuti', 5597),
#  ('macchina', 5188),
#  ('cerca', 1898),
#  ('giardini', 4261),
#  ('piuttosto', 7102),
#  ('approccio', 531),
#  ('seguendo', 9080),
#  ('strada', 10162),
#  ('piscine', 7093),
#  ('limitati', 5081),
#  ('piscina', 7069),
#  ('inferiore', 4718),
#  ('piccola', 6966),
#  ('calda', 1379),
#  ('ben', 1093),
#  ('curati', 2825),
#  ('affaccia', 58),
#  ('sottostante', 9657),
#  ('credo', 2763),
#  ('niente', 6034),
#  ('asciugamani', 658),
#  ('lettini', 5030),
#  ('colazione', 2101),
#  ('sacco', 8789),
#  ('spazio', 9677),
#  ('quando', 8075),
#  ('giugno', 4343),
#  ('essere', 3649),
#  ('agosto', 111),
#  ('andati', 411),
#  ('opzione', 6245),
#  ('mezza', 5508),
#  ('pensione', 6661),
#  ('mangiato', 5286),
#  ('guarda', 4499),
#  ('montagne', 5901),
#  ('italia', 4893),
#  ('continentale', 2578),
#  ('sottofondo', 9653),
#  ('servito', 9236),
#  ('tanto', 10369),
#  ('vario', 11030),
#  ('molto', 5696),
#  ('buono', 1334),
#  ('eccellente', 3438),
#  ('luigi', 5148),
#  ('notte', 6066),
#  ('fatto', 3836),
#  ('bel', 1003),
#  ('cambiamento', 1400),
#  ('potuto', 7411),
#  ('avere', 846),
#  ('pranzo', 7435),
#  ('sostituzione', 9642),
#  ('aspetto', 696),
#  ('bevande', 1148),
#  ('senza', 9172),
#  ('vedere', 11059),
#  ('somma', 9591),
#  ('totale', 10598),
#  ('stata', 9917),
#  ('tuttavia', 10846),
#  ('tratto', 10699),
#  ('potesse', 7384),
#  ('problema', 7739),
#  ('tanti', 10364),
#  ('clienti', 2085),
#  ('sicuro', 9376),
#  ('conto', 2591),
#  ('finale', 3943),
#  ('decisamente', 2914),
#  ('superiore', 10322),
#  ('realtà', 8246),
#  ('camera', 1417),
#  ('belle', 1041),
#  ('sperimentato', 9735),
#  ('alcune', 188),
#  ('notti', 6097),
#  ('buone', 1321),
#  ('dimensioni', 3054),
#  ('bagno', 892),
#  ('adiacente', 38),
#  ('doccia', 3263),
#  ('state', 9943),
#  ('edificio', 3482),
#  ('leggermente', 5001),
#  ('motivo', 5932),
#  ('vedute', 11071),
#  ('migliori', 5544),
#  ('posizione', 7226),
#  ('tranquilla', 10627),
#  ('entrambi', 3553),
#  ('propria', 7813),
#  ('dovrebbe', 3369),
#  ('preferito', 7463),
#  ('direi', 3078),
#  ('famiglie', 3777),
#  ('coloro', 2253),
#  ('problemi', 7746),
#  ('mobilità', 5644),
#  ('gusto', 4521),
#  ('architetto', 556),
#  ('specialità', 9713),
#  ('stessa', 10135),
#  ('completamente', 2345),
#  ('utilizzato', 10985),
#  ('caratteristiche', 1750),
#  ('isola', 4881),
#  ('migliorare', 5533),
#  ('struttura', 10213),
#  ('nuotare', 6141),
#  ('spiaggia', 9756),
#  ('splendida', 9772),
#  ('cristallino', 2773),
#  ('viene', 11220),
#  ('occupato', 6180),
#  ('durante', 3418),
#  ('settimana', 9308),
#  ('difficile', 3040),
#  ('entrare', 3556),
#  ('uscire', 10962),
#  ('elegantemente', 3520),
#  ('scarpe', 8904),
#  ('plastica', 7114),
#  ('sorta', 9632),
#  ('quindi', 8136),
#  ('prendere', 7482),
#  ('prevede', 7605),
#  ('coraggio', 2637),
#  ('affrontare', 92),
#  ('gradini', 4386),
#  ('approfittare', 534),
#  ('deboli', 2898),
#  ('cuore', 2815),
#  ('parlando', 6499),
#  ('noleggiato', 6046),
#  ('bicicletta', 1166),
#  ('mantenere', 5298),
#  ('pasta', 6611),
#  ('presso', 7577),
#  ('poteva', 7391),
#  ('andare', 391),
#  ('parere', 6491),
#  ('trovato', 10797),
#  ('recensioni', 8254),
#  ('negative', 6001),
#  ('trovare', 10774),
#  ('personale', 6774),
#  ('buona', 1286),
#  ('trattati', 10695),
#  ('esigenza', 3603),
#  ('facilità', 3762),
#  ('ideale', 4536),
#  ('riposo', 8566),
#  ('relax', 8333),
#  ('lasciate', 4948),
#  ('nessuno', 6028),
#  ('visitare', 11246),
#  ('prendete', 7492),
#  ('organizzata', 6263),
#  ('contenuti', 2573),
#  ('maggior', 5202),
#  ('parte', 6519),
#  ('appeso', 514),
#  ('treno', 10709),
#  ('grado', 4390),
#  ('finestra', 3948),
#  ('altri', 285),
#  ('stesso', 10137),
#  ('piccole', 6984),
#  ('ottenere', 6306),
#  ('affollato', 90),
#  ('connessione', 2473),
#  ('internet', 4820),
#  ('gratuita', 4455),
#  ('tempi', 10434),
#  ('vacanze', 10988),
#  ('mai soggiornato', 5235),
#  ('esperienza complessiva', 3619),
#  ('prima classe', 7673),
#  ('servizio cordiale', 9260),
#  ('cordiale efficiente', 2645),
#  ('facile raggiungere', 3758),
#  ('raggiungere piedi', 8206),
#  ('piedi verso', 7049),
#  ('verso basso', 11146),
#  ('minuti macchina', 5610),
#  ('strada principale', 10170),
#  ('ben curati', 1105),
#  ('prima colazione', 7674),
#  ('colazione sacco', 2193),
#  ('sacco spazio', 8797),
#  ('mezza pensione', 5510),
#  ('mangiato ristorante', 5290),
#  ('ristorante terrazza', 8648),
#  ('molto buono', 5719),
#  ('buono servizio', 1344),
#  ('servizio eccellente', 9264),
#  ('mangiato fuori', 5288),
#  ('potuto avere', 7412),
#  ('senza mai', 9187),
#  ('essere problema', 3673),
#  ('notti camera', 6100),
#  ('camera buone', 1441),
#  ('buone dimensioni', 1323),
#  ('dimensioni bagno', 3056),
#  ('camere state', 1661),
#  ('edificio principale', 3484),
#  ('posizione tranquilla', 7285),
#  ('dovrebbe essere', 3371),
#  ('problemi mobilità', 7748),
#  ('durante settimana', 3429),
#  ('entrare uscire', 3558),
#  ('quindi prendere', 8155),
#  ('stata esperienza', 9926),
#  ('andare fuori', 398),
#  ('recensioni negative', 8257),
#  ('difficile trovare', 3042),
#  ('trovare personale', 10780),
#  ('posizione ideale', 7251),
#  ('servizio autobus', 9253),
#  ('maggior parte', 5203),
#  ('parte strada', 6540),
#  ('fuori finestra', 4128),
#  ('molto affollato', 5699),
#  ('connessione internet', 2477),
#  ('internet gratuita', 4823),
#  ('stati', 9948),
#  ('sinistra', 9425),
#  ('crociera', 2780),
#  ('gentile', 4186),
#  ('disponibile', 3139),
#  ('pulite', 7909),
#  ('confortevoli', 2458),
#  ('aiutato', 123),
#  ('trasporto', 10683),
#  ('privato', 7731),
#  ('terminal', 10468),
#  ('prezzo', 7625),
#  ('stati notte', 9967),
#  ('notte prima', 6085),
#  ('personale molto', 6819),
#  ('molto gentile', 5779),
#  ('gentile disponibile', 4195),
#  ('disponibile camere', 3144),
#  ('camere pulite', 1647),
#  ('pulite confortevoli', 7918),
#  ('confortevoli colazione', 2461),
#  ('colazione eccellente', 2131),
#  ('prezzo molto', 7647),
#  ('posizionato', 7224),
#  ('torino', 10547),
#  ('circa', 2036),
#  ('fermata', 3888),
#  ('aeroporto', 49),
#  ('stazione', 10067),
#  ('ferroviaria', 3907),
#  ('inoltre', 4760),
#  ('principali', 7720),
#  ('interesse', 4812),
#  ('turistico', 10831),
#  ('raggiungibili', 8212),
#  ('arredata', 577),
#  ('stile', 10143),
#  ('moderno', 5652),
#  ('elegante', 3513),
#  ('scelta', 8923),
#  ('canali', 1699),
#  ('inglese', 4736),
#  ('selezione', 9089),
#  ('qualità', 8042),
#  ('ben posizionato', 1120),
#  ('visitare torino', 11251),
#  ('fermata autobus', 3889),
#  ('autobus aeroporto', 822),
#  ('aeroporto stazione', 56),
#  ('stazione ferroviaria', 10071),
#  ('tutte principali', 10866),
#  ('interesse turistico', 4813),
#  ('raggiungibili piedi', 8213),
#  ('piedi camera', 7023),
#  ('camera ben', 1438),
#  ('ben arredata', 1094),
#  ('arredata stile', 583),
#  ('stile moderno', 10149),
#  ('buona scelta', 1311),
#  ('colazione buono', 2113),
#  ('arrivo', 632),
#  ('cordialità', 2662),
#  ('disponibilità', 3194),
#  ('staff', 9841),
#  ('nuova', 6143),
#  ('moderne', 5649),
#  ('arredate', 584),
#  ('ottima', 6311),
#  ('ritornerò', 8701),
#  ('ottimo', 6354),
#  ('viaggi', 11159),
#  ('lavoro', 4984),
#  ('soggiorno', 9536),
#  ('città', 2054),
#  ('raccomandato', 8171),
#  ('cordialità disponibilità', 2663),
#  ('disponibilità staff', 3198),
#  ('qualità camere', 8045),
#  ('molto moderne', 5801),
#  ('ben arredate', 1095),
#  ('arredate colazione', 586),
#  ('colazione ottima', 2167),
#  ('viaggi lavoro', 11161),
#  ('cortese', 2691),
#  ('lasciare', 4942),
#  ('bagagli', 877),
#  ('mattino', 5389),
#  ('presto', 7594),
#  ('iniziare', 4750),
#  ('immediatamente', 4573),
#  ('bellissimo', 1066),
#  ('stato', 9983),
#  ('superlativo', 10326),
#  ('consiglio', 2533),
#  ('vivamente', 11268),
#  ('mezzi', 5512),
#  ('tornerei', 10565),
#  ('sicuramente', 9352),
#  ('soggiornato notti', 9521),
#  ('molto cortese', 5746),
#  ('stati grado', 9961),
#  ('lasciare bagagli', 4943),
#  ('mattino presto', 5391),
#  ('ristorante stato', 8647),
#  ('consiglio vivamente', 2547),
#  ('ottima posizione', 6327),
#  ('mezzi trasporto', 5514),
#  ('tornerei sicuramente', 10570),
#  ('palace', 6429),
#  ('fidanzato', 3930),
#  ('concerto', 2396),
#  ('certo', 1914),
#  ('perchè', 6671),
#  ('vicina', 11174),
#  ('luogo', 5171),
#  ('bella', 1013),
#  ('ampia', 356),
#  ('pulita', 7889),
#  ('balconcino', 945),
#  ('vasta', 11039),
#  ('dolce', 3288),
#  ('salato', 8804),
#  ('consigliato', 2522),
#  ('necessità', 5999),
#  ('stare', 9912),
#  ('pieno', 7054),
#  ('centro', 1872),
#  ('passi', 6596),
#  ('metropolitana', 5489),
#  ('grandissima', 4450),
#  ('comodità', 2298),
#  ('bella struttura', 1038),
#  ('struttura camera', 10218),
#  ('camera ampia', 1424),
#  ('ampia ben', 358),
#  ('arredata pulita', 582),
#  ('colazione vasta', 2223),
#  ('vasta scelta', 11041),
#  ('scelta dolce', 8927),
#  ('dolce salato', 3290),
#  ('ottima qualità', 6331),
#  ('pieno centro', 7055),
#  ('centro passi', 1888),
#  ('passi fermata', 6600),
#  ('fermata metropolitana', 3891),
#  ('mestre', 5468),
#  ('comodissima', 2294),
#  ('stanza', 9871),
#  ('ascensore', 651),
#  ('interno', 4828),
#  ('piani', 6917),
#  ('superiori', 10323),
#  ('gratuito', 4461),
#  ('usufruito', 10970),
#  ('passi stazione', 6606),
#  ('stazione mestre', 10073),
#  ('stanza pulita', 9889),
#  ('piani superiori', 6918),
#  ('personale gentile', 6806),
#  ('qualche', 8020),
#  ('annessa', 444),
#  ('mozzafiato', 5938),
#  ('panorama', 6449),
#  ('paragonabile', 6463),
#  ('pochi', 7123),
#  ('purtroppo', 8005),
#  ('ubicato', 10872),
#  ('posto', 7344),
#  ('raggiungibile', 8210),
#  ('percorso', 6698),
#  ('stretta', 10208),
#  ('doppio', 3323),
#  ('senso', 9148),
#  ('marcia', 5308),
#  ('compenso', 2319),
#  ('dispone', 3134),
#  ('posti', 7339),
#  ('valutazione', 11004),
#  ('limitata', 5079),
#  ('impressione', 4627),
#  ('buffet', 1272),
#  ('comoda', 2281),
#  ('stelle', 10093),
#  ('meritate', 5455),
#  ('strada stretta', 10174),
#  ('stata buona', 9921),
#  ('stelle meritate', 10110),
#  ('centrale', 1849),
#  ('particolare', 6551),
#  ('carino', 1762),
#  ('gentilissimo', 4225),
#  ('prezzi', 7615),
#  ('porta', 7168),
#  ('ristoranti', 8654),
#  ('ampie', 365),
#  ('balcone', 946),
#  ('unico', 10927),
#  ('scarico', 8901),
#  ('tutta', 10833),
#  ('centrale molto', 1858),
#  ('molto particolare', 5805),
#  ('carino personale', 1763),
#  ('personale gentilissimo', 6809),
#  ('prezzi contenuti', 7618),
#  ('stazione porta', 10080),
#  ('camere ampie', 1598),
#  ('estate', 3687),
#  ('scorsa', 9005),
#  ('moglie', 5666),
#  ('figlia', 3936),
#  ('castellabate', 1803),
#  ('capitato', 1734),
#  ('grazioso', 4480),
#  ('verità', 11140),
#  ('trovati', 10792),
#  ('centralissima', 1866),
#  ('metri', 5472),
#  ('proprio', 7823),
#  ('cercavamo', 1905),
#  ('bimba', 1176),
#  ('qualsiasi', 8064),
#  ('grandi', 4439),
#  ('sempre', 9116),
#  ('cucina', 2788),
#  ('tradizionale', 10607),
#  ('penso', 6664),
#  ('ritorneremo', 8698),
#  ('moglie figlia', 5667),
#  ('mai stato', 5238),
#  ('trovati molto', 10795),
#  ('pochi metri', 7127),
#  ('trovato personale', 10808),
#  ('disponibile qualsiasi', 3173),
#  ('qualsiasi esigenza', 8068),
#  ('camere molto', 1637),
#  ('molto grandi', 5784),
#  ('grandi confortevoli', 4445),
#  ('confortevoli molto', 2462),
#  ('penso proprio', 6665),
#  ('piacevole', 6894),
#  ('lobby', 5110),
#  ('aiutarvi', 121),
#  ('stanze', 9897),
#  ('vasca', 11031),
#  ('idromassaggio', 4544),
#  ('rilassarsi', 8487),
#  ('lungo', 5161),
#  ('situato', 9438),
#  ('buoni', 1326),
#  ('mangiare', 5281),
#  ('dintorni', 3070),
#  ('unica', 10912),
#  ('piaciuta', 6909),
#  ('lunga', 5155),
#  ('passeggiata', 6592),
#  ('assolutamente', 733),
#  ('tempo', 10437),
#  ('ordinato', 6256),
#  ('anticipo', 460),
#  ('piaciuto', 6912),
#  ('provare', 7862),
#  ('benessere', 1134),
#  ('costruzione', 2743),
#  ('prima stata', 7695),
#  ('esperienza molto', 3624),
#  ('molto piacevole', 5807),
#  ('personale stato', 6850),
#  ('stato ottimo', 10032),
#  ('stanze bagno', 9899),
#  ('bagno buone', 902),
#  ('vasca idromassaggio', 11034),
#  ('molto ben', 5714),
#  ('ben situato', 1127),
#  ('situato proprio', 9451),
#  ('proprio stazione', 7841),
#  ('stazione centrale', 10069),
#  ('posti mangiare', 7340),
#  ('servizio camera', 9255),
#  ('camera buono', 1442),
#  ('centro benessere', 1873),
#  ('guardare', 4502),
#  ('avanti', 841),
#  ('ritorno', 8704),
#  ('incantevole', 4643),
#  ('critiche', 2778),
#  ('funzionava', 4111),
#  ('sentito', 9163),
#  ('feedback', 3874),
#  ('altro', 302),
#  ('ospite', 6290),
#  ('aggiunta', 107),
#  ('usurati', 10972),
#  ('detto', 2998),
#  ('alcuna', 186),
#  ('soggiornato prima', 9524),
#  ('incantevole camera', 4644),
#  ('camera ottima', 1515),
#  ('funzionava camera', 4112),
#  ('altro ospite', 309),
#  ('tornerei senza', 10569),
#  ('senza alcuna', 9174),
#  ('camere confortevoli', 1615),
#  ('confortevoli pulite', 2464),
#  ('pulite colazione', 7916),
#  ('soltanto', 9588),
#  ('lasciato', 4952),
#  ('offre', 6195),
#  ('splendide', 9781),
#  ('dista', 3208),
#  ('breve', 1244),
#  ('tragitto', 10617),
#  ('lontano', 5131),
#  ('estremamente', 3706),
#  ('escursione', 3594),
#  ('barca', 971),
#  ('murano', 5949),
#  ('gratuitamente', 4458),
#  ('vetro', 11154),
#  ('veneziano', 11090),
#  ('lavorando', 4976),
#  ('valeva', 10991),
#  ('splendide vedute', 9782),
#  ('personale estremamente', 6801),
#  ('estremamente cordiale', 3710),
#  ('cordiale camere', 2642),
#  ('molto bella', 5710),
#  ('appena', 496),
#  ('sufficiente', 10285),
#  ('insopportabile', 4791),
#  ('moderna', 5647),
#  ('vassoio', 11038),
#  ('sporca', 9790),
#  ('davanti', 2861),
#  ('segno', 9077),
#  ('trasferito', 10675),
#  ('telefono', 10425),
#  ('collegare', 2233),
#  ('briciole', 1252),
#  ('comodino', 2293),
#  ('subito', 10268),
#  ('asciugamano', 662),
#  ('superficie', 10320),
#  ('deludente', 2953),
#  ('atteggiamento', 758),
#  ('freddo', 4054),
#  ('ospiti', 6291),
#  ('provenienti', 7872),
#  ('quasi', 8115),
#  ('potrebbe', 7400),
#  ('questioni', 8134),
#  ('bianco', 1159),
#  ('ricevere', 8405),
#  ('trattamenti', 10689),
#  ('diversi', 3244),
#  ('milano', 5552),
#  ('fascino', 3818),
#  ('confermato', 2435),
#  ('appena sufficiente', 507),
#  ('tuttavia quando', 10850),
#  ('andati camera', 412),
#  ('camera proprio', 1541),
#  ('proprio davanti', 7829),
#  ('davanti porta', 2864),
#  ('interno camera', 4830),
#  ('personale personale', 6826),
#  ('personale reception', 6838),
#  ('reception ristorante', 8297),
#  ('potrebbe essere', 7402),
#  ('pochissimi', 7135),
#  ('ingresso', 4742),
#  ('laterale', 4961),
#  ('critica', 2776),
#  ('normale', 6054),
#  ('intorno', 4847),
#  ('stazioni', 10086),
#  ('pulito', 7940),
#  ('curato', 2828),
#  ('spazi', 9673),
#  ('comuni', 2383),
#  ('ricca', 8389),
#  ('copertura', 2627),
#  ('telefonica', 10423),
#  ('complesso', 2331),
#  ('città personale', 2064),
#  ('cortese efficiente', 2697),
#  ('pulito ben', 7942),
#  ('ben curato', 1106),
#  ('curato camere', 2829),
#  ('spazi comuni', 9674),
#  ('qualità colazione', 8046),
#  ('buono ristorante', 1343),
#  ('ristorante interno', 8628),
#  ('complesso ottimo', 2337),
#  ('ottimo stelle', 6382),
#  ('girare', 4331),
#  ('spaziosi', 9704),
#  ('puliti', 7934),
#  ('cortesia', 2704),
#  ('varia', 11015),
#  ('rapporto', 8231),
#  ('parcheggio', 6469),
#  ('pagamento', 6401),
#  ('comodo', 2299),
#  ('volentieri', 11281),
#  ('complimenti', 2356),
#  ('situato posizione', 9450),
#  ('posizione comoda', 7239),
#  ('camera bagno', 1434),
#  ('staff colazione', 9844),
#  ('colazione varia', 2221),
#  ('ottimo rapporto', 6376),
#  ('rapporto qualità', 8234),
#  ('qualità prezzo', 8052),
#  ('parcheggio pagamento', 6478),
#  ('molto comodo', 5737),
#  ('tornerei volentieri', 10571),
#  ('sgradevole', 9341),
#  ('punti', 7990),
#  ('piccolissima', 6998),
#  ('matrimoniale', 5371),
#  ('superior', 10321),
#  ('dotata', 3337),
#  ('letto', 5033),
#  ('francese', 4043),
#  ('fastidiosa', 3822),
#  ('parlare', 6502),
#  ('finta', 3965),
#  ('difficoltà', 3045),
#  ('posteggio', 7337),
#  ('peraltro', 6669),
#  ('carissimo', 1765),
#  ('persona', 6767),
#  ('giorno', 4305),
#  ('tassa', 10392),
#  ('offriva', 6204),
#  ('maleodoranti', 5252),
#  ('bicchieri', 1164),
#  ('povero', 7429),
#  ('entra', 3550),
#  ('eleganza', 3522),
#  ('nulla', 6130),
#  ('brutto', 1264),
#  ('albergo', 139),
#  ('camera matrimoniale', 1499),
#  ('letto francese', 5047),
#  ('cortesia personale', 2707),
#  ('difficoltà trovare', 3046),
#  ('tassa soggiorno', 10393),
#  ('colazione offriva', 2166),
#  ('prenotato', 7505),
#  ('compleanno', 2325),
#  ('attraverso', 796),
#  ('eccellenti', 3457),
#  ('guardato', 4506),
#  ('opzioni', 6246),
#  ('alberghi', 127),
#  ('controllato', 2602),
#  ('advisor', 46),
#  ('oriente', 6270),
#  ('meglio', 5409),
#  ('arrivati', 611),
#  ('economico', 3479),
#  ('rapido', 8230),
#  ('motore', 5933),
#  ('vento', 11110),
#  ('capelli', 1721),
#  ('lasciati', 4951),
#  ('migliore', 5537),
#  ('tranquillo', 10637),
#  ('canale', 1695),
#  ('entro', 3567),
#  ('labirinto', 4908),
#  ('sembrato', 9099),
#  ('ubicazione', 10874),
#  ('ragazza', 8187),
#  ('società', 9463),
#  ('forma', 3991),
#  ('pesce', 6869),
#  ('testa', 10508),
#  ('ovest', 6386),
#  ('caffè', 1366),
#  ('vicoli', 11217),
#  ('oltre', 6213),
#  ('turistiche', 10829),
#  ('piazza', 6951),
#  ('marco', 5310),
#  ('ponte', 7159),
#  ('rialto', 8379),
#  ('arredamento', 569),
#  ('archi', 555),
#  ('mobili', 5639),
#  ('tornare', 10553),
#  ('indietro', 4693),
#  ('potete', 7386),
#  ('drink', 3400),
#  ('godersi', 4364),
#  ('vicinanze', 11181),
#  ('sembravano', 9105),
#  ('principalmente', 7722),
#  ('americani', 339),
#  ('inglesi', 4739),
#  ('tedeschi', 10415),
#  ('eccezione', 3474),
#  ('eseguire', 3597),
#  ('sperimentare', 9734),
#  ('grand', 4395),
#  ('canal', 1693),
#  ('divertente', 3247),
#  ('torta', 10591),
#  ('cioccolato', 2033),
#  ('inaspettato', 4640),
#  ('preso', 7571),
#  ('cortile', 2711),
#  ('giardino', 4262),
#  ('incredibile', 4675),
#  ('andateci', 410),
#  ('adesso', 37),
#  ('aspettando', 669),
#  ('prenotato soggiorno', 7522),
#  ('soggiorno notti', 9559),
#  ('compleanno moglie', 2326),
#  ('sempre stati', 9139),
#  ('proprio fuori', 7834),
#  ('parte superiore', 6541),
#  ('sacco ristoranti', 8793),
#  ('minuti passeggiata', 5616),
#  ('piazza marco', 6956),
#  ('marco ponte', 5320),
#  ('ponte rialto', 7161),
#  ('tornare indietro', 10555),
#  ('personale senza', 6845),
#  ('grand canal', 4396),
#  ('stato molto', 10027),
#  ('molto divertente', 5764),
#  ('isola murano', 4882),
#  ('colazione buffet', 2110),
#  ('piaciuto molto', 6915),
#  ('compagno', 2315),
#  ('splendido', 9784),
#  ('soprattutto', 9603),
#  ('stupenda', 10259),
#  ('salata', 8801),
#  ('prenotare', 7500),
#  ('godere', 4363),
#  ('tranquillità', 10636),
#  ('altra', 264),
#  ('coppia', 2629),
#  ('esterna', 3688),
#  ('parco', 6484),
#  ('circonda', 2042),
#  ('piacevoli', 6902),
#  ('girato', 4336),
#  ('toscana', 10595),
#  ('completo', 2352),
#  ('torneremo', 10575),
#  ('camere belle', 1603),
#  ('belle pulite', 1046),
#  ('pulite ottima', 7927),
#  ('qualità personale', 8050),
#  ('stato sempre', 10055),
#  ('sempre gentile', 9125),
#  ('gentile soprattutto', 4209),
#  ('molto grande', 5783),
#  ('altra coppia', 266),
#  ('piscina esterna', 7075),
#  ('mattina', 5379),
#  ('alloggiato', 233),
#  ('assoluto', 744),
#  ('incantevoli', 4649),
#  ('vicino', 11191),
#  ('negozi', 6005),
#  ('tranquillamente', 10633),
#  ('esitate', 3611),
#  ('soggiornare', 9498),
#  ('appena arrivati', 498),
#  ('personale incantevole', 6812),
#  ('incantevole camere', 4645),
#  ('camere incantevoli', 1630),
#  ('vicino piazza', 11209),
#  ('ristoranti negozi', 8662),
#  ('tempo stesso', 10443),
#  ('utile', 10975),
#  ('troppo', 10725),
#  ('impersonale', 4599),
#  ('corridoi', 2678),
#  ('mobilio', 5643),
#  ('pesante', 6867),
#  ('possibilità', 7314),
#  ('provato', 7868),
#  ('servizi', 9240),
#  ('neanche', 5988),
#  ('inclusa', 4657),
#  ('fretta', 4069),
#  ('ambiente', 329),
#  ('finita', 3960),
#  ('residence', 8352),
#  ('spero', 9737),
#  ('troppo grande', 10736),
#  ('letto comodo', 5041),
#  ('colazione inclusa', 2144),
#  ('principe', 7723),
#  ('scritto', 9016),
#  ('recensione', 8251),
#  ('davvero', 2867),
#  ('gioiello', 4275),
#  ('meraviglioso', 5443),
#  ('spaziose', 9691),
#  ('quest', 8129),
#  ('ultima', 10889),
#  ('junior', 4903),
#  ('suite', 10297),
#  ('rinnovata', 8541),
#  ('tecnologia', 10414),
#  ('generose', 4178),
#  ('cocktail', 2094),
#  ('incredibili', 4679),
#  ('grazie', 4468),
#  ('modesto', 5659),
#  ('roccia', 8734),
#  ('portineria', 7202),
#  ('personale meraviglioso', 6818),
#  ('camere spaziose', 1658),
#  ('quest ultima', 8131),
#  ('junior suite', 4904),
#  ('eccellente molto', 3444),
#  ('nemmeno', 6009),
#  ('grosse', 4485),
#  ('pretese', 7602),
#  ('decente', 2901),
#  ('stonata', 10154),
#  ('scontroso', 8994),
#  ('professionale', 7759),
#  ('cordiali', 2658),
#  ('sembra', 9090),
#  ('piacere', 6887),
#  ('andate', 408),
#  ('stanze piccole', 9906),
#  ('colazione decente', 2125),
#  ('unica stonata', 10923),
#  ('potete trovare', 7389),
#  ('trovata', 10788),
#  ('benissimo', 1137),
#  ('primis', 7708),
#  ('gentilissimi', 4224),
#  ('disponibili', 3189),
#  ('disposizione', 3201),
#  ('richieste', 8421),
#  ('esigenze', 3604),
#  ('bellissima', 1054),
#  ('nessun', 6012),
#  ('difetto', 3035),
#  ('deliziosi', 2950),
#  ('squisiti', 9829),
#  ('tornerò', 10585),
#  ('trovata benissimo', 10789),
#  ('staff cordiale', 9845),
#  ('sempre disposizione', 9123),
#  ('buffet colazione', 1275),
#  ('bello', 1074),
#  ('giudizio', 4340),
#  ('puzzava', 8011),
#  ('sigaretta', 9377),
#  ('forse', 4019),
#  ('ragazzo', 8194),
#  ('portava', 7195),
#  ('valigie', 10997),
#  ('aperitivo', 480),
#  ('incluso', 4664),
#  ('pacchetto', 6392),
#  ('atteso', 779),
#  ('considerata', 2504),
#  ('prenotazione', 7526),
#  ('dovevamo', 3365),
#  ('orario', 6249),
#  ('previsto', 7610),
#  ('check', 1924),
#  ('dovuto', 3382),
#  ('assurdo', 750),
#  ('paghi', 6427),
#  ('resto', 8370),
#  ('qualcuno', 8035),
#  ('ragazze', 8189),
#  ('albergo molto', 149),
#  ('molto bello', 5713),
#  ('circa minuti', 2039),
#  ('altri ospiti', 292),
#  ('altro ristorante', 312),
#  ('dovuto lasciare', 3392),
#  ('mentre', 5426),
#  ('soggiornate', 9505),
#  ('deciso', 2916),
#  ('esplorare', 3634),
#  ('decidere', 2907),
#  ('piacerebbe', 6889),
#  ('scelto', 8944),
#  ('vicinanza', 11177),
#  ('teatro', 10409),
#  ('opera', 6230),
#  ('molte', 5676),
#  ('altre', 273),
#  ('attrazioni', 799),
#  ('rimasti', 8504),
#  ('incantati', 4641),
#  ('momento', 5887),
#  ('entrati', 3561),
#  ('calorosamente', 1396),
#  ('indicato', 4690),
#  ('confortevole', 2443),
#  ('divano', 3233),
#  ('poltrona', 7145),
#  ('scrivania', 9017),
#  ('separata', 9205),
#  ('nuovo', 6152),
#  ('armadio', 563),
#  ('sedile', 9062),
#  ('dimensione', 3052),
#  ('spina', 9768),
#  ('chiunque', 2000),
#  ('bisogno', 1190),
#  ('perfetta', 6711),
#  ('scelte', 8943),
#  ('viaggiano', 11166),
#  ('dieta', 3031),
#  ('occasione', 6166),
#  ('sorseggiare', 9631),
#  ...]

# %%
help(WordCloud)
# Out:
# Help on class WordCloud in module wordcloud.wordcloud:
#
# class WordCloud(builtins.object)
#  |  WordCloud(font_path=None, width=400, height=200, margin=2, ranks_only=None, prefer_horizontal=0.9, mask=None, scale=1, color_func=None, max_words=200, min_font_size=4, stopwords=None, random_state=None, background_color='black', max_font_size=None, font_step=1, mode='RGB', relative_scaling='auto', regexp=None, collocations=True, colormap=None, normalize_plurals=True, contour_width=0, contour_color='black', repeat=False, include_numbers=False, min_word_length=0)
#  |
#  |  Word cloud object for generating and drawing.
#  |
#  |  Parameters
#  |  ----------
#  |  font_path : string
#  |      Font path to the font that will be used (OTF or TTF).
#  |      Defaults to DroidSansMono path on a Linux machine. If you are on
#  |      another OS or don't have this font, you need to adjust this path.
#  |
#  |  width : int (default=400)
#  |      Width of the canvas.
#  |
#  |  height : int (default=200)
#  |      Height of the canvas.
#  |
#  |  prefer_horizontal : float (default=0.90)
#  |      The ratio of times to try horizontal fitting as opposed to vertical.
#  |      If prefer_horizontal < 1, the algorithm will try rotating the word
#  |      if it doesn't fit. (There is currently no built-in way to get only
#  |      vertical words.)
#  |
#  |  mask : nd-array or None (default=None)
#  |      If not None, gives a binary mask on where to draw words. If mask is not
#  |      None, width and height will be ignored and the shape of mask will be
#  |      used instead. All white (#FF or #FFFFFF) entries will be considerd
#  |      "masked out" while other entries will be free to draw on. [This
#  |      changed in the most recent version!]
#  |
#  |  contour_width: float (default=0)
#  |      If mask is not None and contour_width > 0, draw the mask contour.
#  |
#  |  contour_color: color value (default="black")
#  |      Mask contour color.
#  |
#  |  scale : float (default=1)
#  |      Scaling between computation and drawing. For large word-cloud images,
#  |      using scale instead of larger canvas size is significantly faster, but
#  |      might lead to a coarser fit for the words.
#  |
#  |  min_font_size : int (default=4)
#  |      Smallest font size to use. Will stop when there is no more room in this
#  |      size.
#  |
#  |  font_step : int (default=1)
#  |      Step size for the font. font_step > 1 might speed up computation but
#  |      give a worse fit.
#  |
#  |  max_words : number (default=200)
#  |      The maximum number of words.
#  |
#  |  stopwords : set of strings or None
#  |      The words that will be eliminated. If None, the build-in STOPWORDS
#  |      list will be used. Ignored if using generate_from_frequencies.
#  |
#  |  background_color : color value (default="black")
#  |      Background color for the word cloud image.
#  |
#  |  max_font_size : int or None (default=None)
#  |      Maximum font size for the largest word. If None, height of the image is
#  |      used.
#  |
#  |  mode : string (default="RGB")
#  |      Transparent background will be generated when mode is "RGBA" and
#  |      background_color is None.
#  |
#  |  relative_scaling : float (default='auto')
#  |      Importance of relative word frequencies for font-size.  With
#  |      relative_scaling=0, only word-ranks are considered.  With
#  |      relative_scaling=1, a word that is twice as frequent will have twice
#  |      the size.  If you want to consider the word frequencies and not only
#  |      their rank, relative_scaling around .5 often looks good.
#  |      If 'auto' it will be set to 0.5 unless repeat is true, in which
#  |      case it will be set to 0.
#  |
#  |      .. versionchanged: 2.0
#  |          Default is now 'auto'.
#  |
#  |  color_func : callable, default=None
#  |      Callable with parameters word, font_size, position, orientation,
#  |      font_path, random_state that returns a PIL color for each word.
#  |      Overwrites "colormap".
#  |      See colormap for specifying a matplotlib colormap instead.
#  |      To create a word cloud with a single color, use
#  |      ``color_func=lambda *args, **kwargs: "white"``.
#  |      The single color can also be specified using RGB code. For example
#  |      ``color_func=lambda *args, **kwargs: (255,0,0)`` sets color to red.
#  |
#  |  regexp : string or None (optional)
#  |      Regular expression to split the input text into tokens in process_text.
#  |      If None is specified, ``r"\w[\w']+"`` is used. Ignored if using
#  |      generate_from_frequencies.
#  |
#  |  collocations : bool, default=True
#  |      Whether to include collocations (bigrams) of two words. Ignored if using
#  |      generate_from_frequencies.
#  |
#  |
#  |      .. versionadded: 2.0
#  |
#  |  colormap : string or matplotlib colormap, default="viridis"
#  |      Matplotlib colormap to randomly draw colors from for each word.
#  |      Ignored if "color_func" is specified.
#  |
#  |      .. versionadded: 2.0
#  |
#  |  normalize_plurals : bool, default=True
#  |      Whether to remove trailing 's' from words. If True and a word
#  |      appears with and without a trailing 's', the one with trailing 's'
#  |      is removed and its counts are added to the version without
#  |      trailing 's' -- unless the word ends with 'ss'. Ignored if using
#  |      generate_from_frequencies.
#  |
#  |  repeat : bool, default=False
#  |      Whether to repeat words and phrases until max_words or min_font_size
#  |      is reached.
#  |
#  |  include_numbers : bool, default=False
#  |      Whether to include numbers as phrases or not.
#  |
#  |  min_word_length : int, default=0
#  |      Minimum number of letters a word must have to be included.
#  |
#  |  Attributes
#  |  ----------
#  |  ``words_`` : dict of string to float
#  |      Word tokens with associated frequency.
#  |
#  |      .. versionchanged: 2.0
#  |          ``words_`` is now a dictionary
#  |
#  |  ``layout_`` : list of tuples (string, int, (int, int), int, color))
#  |      Encodes the fitted word cloud. Encodes for each word the string, font
#  |      size, position, orientation and color.
#  |
#  |  Notes
#  |  -----
#  |  Larger canvases with make the code significantly slower. If you need a
#  |  large word cloud, try a lower canvas size, and set the scale parameter.
#  |
#  |  The algorithm might give more weight to the ranking of the words
#  |  than their actual frequencies, depending on the ``max_font_size`` and the
#  |  scaling heuristic.
#  |
#  |  Methods defined here:
#  |
#  |  __array__(self)
#  |      Convert to numpy array.
#  |
#  |      Returns
#  |      -------
#  |      image : nd-array size (width, height, 3)
#  |          Word cloud image as numpy matrix.
#  |
#  |  __init__(self, font_path=None, width=400, height=200, margin=2, ranks_only=None, prefer_horizontal=0.9, mask=None, scale=1, color_func=None, max_words=200, min_font_size=4, stopwords=None, random_state=None, background_color='black', max_font_size=None, font_step=1, mode='RGB', relative_scaling='auto', regexp=None, collocations=True, colormap=None, normalize_plurals=True, contour_width=0, contour_color='black', repeat=False, include_numbers=False, min_word_length=0)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  fit_words(self, frequencies)
#  |      Create a word_cloud from words and frequencies.
#  |
#  |      Alias to generate_from_frequencies.
#  |
#  |      Parameters
#  |      ----------
#  |      frequencies : dict from string to float
#  |          A contains words and associated frequency.
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  generate(self, text)
#  |      Generate wordcloud from text.
#  |
#  |      The input "text" is expected to be a natural text. If you pass a sorted
#  |      list of words, words will appear in your output twice. To remove this
#  |      duplication, set ``collocations=False``.
#  |
#  |      Alias to generate_from_text.
#  |
#  |      Calls process_text and generate_from_frequencies.
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  generate_from_frequencies(self, frequencies, max_font_size=None)
#  |      Create a word_cloud from words and frequencies.
#  |
#  |      Parameters
#  |      ----------
#  |      frequencies : dict from string to float
#  |          A contains words and associated frequency.
#  |
#  |      max_font_size : int
#  |          Use this font-size instead of self.max_font_size
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  generate_from_text(self, text)
#  |      Generate wordcloud from text.
#  |
#  |      The input "text" is expected to be a natural text. If you pass a sorted
#  |      list of words, words will appear in your output twice. To remove this
#  |      duplication, set ``collocations=False``.
#  |
#  |      Calls process_text and generate_from_frequencies.
#  |
#  |      ..versionchanged:: 1.2.2
#  |          Argument of generate_from_frequencies() is not return of
#  |          process_text() any more.
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  process_text(self, text)
#  |      Splits a long text into words, eliminates the stopwords.
#  |
#  |      Parameters
#  |      ----------
#  |      text : string
#  |          The text to be processed.
#  |
#  |      Returns
#  |      -------
#  |      words : dict (string, int)
#  |          Word tokens with associated frequency.
#  |
#  |      ..versionchanged:: 1.2.2
#  |          Changed return type from list of tuples to dict.
#  |
#  |      Notes
#  |      -----
#  |      There are better ways to do word tokenization, but I don't want to
#  |      include all those things.
#  |
#  |  recolor(self, random_state=None, color_func=None, colormap=None)
#  |      Recolor existing layout.
#  |
#  |      Applying a new coloring is much faster than generating the whole
#  |      wordcloud.
#  |
#  |      Parameters
#  |      ----------
#  |      random_state : RandomState, int, or None, default=None
#  |          If not None, a fixed random state is used. If an int is given, this
#  |          is used as seed for a random.Random state.
#  |
#  |      color_func : function or None, default=None
#  |          Function to generate new color from word count, font size, position
#  |          and orientation.  If None, self.color_func is used.
#  |
#  |      colormap : string or matplotlib colormap, default=None
#  |          Use this colormap to generate new colors. Ignored if color_func
#  |          is specified. If None, self.color_func (or self.color_map) is used.
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  to_array(self)
#  |      Convert to numpy array.
#  |
#  |      Returns
#  |      -------
#  |      image : nd-array size (width, height, 3)
#  |          Word cloud image as numpy matrix.
#  |
#  |  to_file(self, filename)
#  |      Export to image file.
#  |
#  |      Parameters
#  |      ----------
#  |      filename : string
#  |          Location to write to.
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  to_html(self)
#  |
#  |  to_image(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
